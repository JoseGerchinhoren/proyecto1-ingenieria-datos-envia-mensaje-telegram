# %% [markdown]
# <img src=https://i.ytimg.com/vi/knxlmCVFAZI/maxresdefault.jpg>

# %%
import pandas as pd
import requests
from tqdm import tqdm
from telegram_config import *

# %% [markdown]
# # Armado de la URL

# %%
query = 'Salta'
api_key = API_KEY_WAPI

url_clima = 'http://api.weatherapi.com/v1/forecast.json?key='+api_key+'&q='+query+'&days=1&aqi=no&alerts=no'
url_clima
# Out:
# 'http://api.weatherapi.com/v1/forecast.json?key=f3cf65ff7ae64bccad9210657220807&q=Salta&days=1&aqi=no&alerts=no'

# %%
response = requests.get(url_clima).json()

# %%
response
# Out:
# {'location': {'name': 'Salta',
#   'region': 'Salta',
#   'country': 'Argentina',
#   'lat': -24.78,
#   'lon': -65.42,
#   'tz_id': 'America/Argentina/Salta',
#   'localtime_epoch': 1709327815,
#   'localtime': '2024-03-01 18:16'},
#  'current': {'last_updated_epoch': 1709327700,
#   'last_updated': '2024-03-01 18:15',
#   'temp_c': 27.0,
#   'temp_f': 80.6,
#   'is_day': 1,
#   'condition': {'text': 'Partly cloudy',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#    'code': 1003},
#   'wind_mph': 6.9,
#   'wind_kph': 11.2,
#   'wind_degree': 50,
#   'wind_dir': 'NE',
#   'pressure_mb': 1015.0,
#   'pressure_in': 29.97,
#   'precip_mm': 0.08,
#   'precip_in': 0.0,
#   'humidity': 66,
#   'cloud': 50,
#   'feelslike_c': 29.0,
#   'feelslike_f': 84.1,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'uv': 7.0,
#   'gust_mph': 11.4,
#   'gust_kph': 18.4},
#  'forecast': {'forecastday': [{'date': '2024-03-01',
#     'date_epoch': 1709251200,
#     'day': {'maxtemp_c': 28.8,
#      'maxtemp_f': 83.8,
#      'mintemp_c': 17.6,
#      'mintemp_f': 63.7,
#      'avgtemp_c': 22.6,
#      'avgtemp_f': 72.6,
#      'maxwind_mph': 5.6,
#      'maxwind_kph': 9.0,
#      'totalprecip_mm': 1.33,
#      'totalprecip_in': 0.05,
#      'totalsnow_cm': 0.0,
#      'avgvis_km': 9.8,
#      'avgvis_miles': 6.0,
#      'avghumidity': 73,
#      'daily_will_it_rain': 1,
#      'daily_chance_of_rain': 89,
#      'daily_will_it_snow': 0,
#      'daily_chance_of_snow': 0,
#      'condition': {'text': 'Patchy rain nearby',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#       'code': 1063},
#      'uv': 11.0},
#     'astro': {'sunrise': '07:17 AM',
#      'sunset': '07:51 PM',
#      'moonrise': '11:21 PM',
#      'moonset': '12:20 PM',
#      'moon_phase': 'Waning Gibbous',
#      'moon_illumination': 75,
#      'is_moon_up': 0,
#      'is_sun_up': 0},
#     'hour': [{'time_epoch': 1709262000,
#       'time': '2024-03-01 00:00',
#       'temp_c': 18.7,
#       'temp_f': 65.7,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 4.5,
#       'wind_kph': 7.2,
#       'wind_degree': 288,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.99,
#       'precip_mm': 0.13,
#       'precip_in': 0.01,
#       'snow_cm': 0.0,
#       'humidity': 87,
#       'cloud': 86,
#       'feelslike_c': 18.8,
#       'feelslike_f': 65.8,
#       'windchill_c': 18.8,
#       'windchill_f': 65.8,
#       'heatindex_c': 18.8,
#       'heatindex_f': 65.8,
#       'dewpoint_c': 16.6,
#       'dewpoint_f': 61.8,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.4,
#       'gust_kph': 15.1,
#       'uv': 1.0},
#      {'time_epoch': 1709265600,
#       'time': '2024-03-01 01:00',
#       'temp_c': 19.5,
#       'temp_f': 67.2,
#       'is_day': 0,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 4.5,
#       'wind_kph': 7.2,
#       'wind_degree': 281,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.97,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 86,
#       'cloud': 25,
#       'feelslike_c': 19.6,
#       'feelslike_f': 67.2,
#       'windchill_c': 19.6,
#       'windchill_f': 67.2,
#       'heatindex_c': 19.6,
#       'heatindex_f': 67.2,
#       'dewpoint_c': 17.1,
#       'dewpoint_f': 62.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.4,
#       'gust_kph': 15.1,
#       'uv': 1.0},
#      {'time_epoch': 1709269200,
#       'time': '2024-03-01 02:00',
#       'temp_c': 19.6,
#       'temp_f': 67.2,
#       'is_day': 0,
#       'condition': {'text': 'Clear ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 4.3,
#       'wind_kph': 6.8,
#       'wind_degree': 278,
#       'wind_dir': 'W',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.96,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 84,
#       'cloud': 21,
#       'feelslike_c': 19.6,
#       'feelslike_f': 67.2,
#       'windchill_c': 19.6,
#       'windchill_f': 67.2,
#       'heatindex_c': 19.6,
#       'heatindex_f': 67.2,
#       'dewpoint_c': 16.9,
#       'dewpoint_f': 62.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.9,
#       'gust_kph': 14.4,
#       'uv': 1.0},
#      {'time_epoch': 1709272800,
#       'time': '2024-03-01 03:00',
#       'temp_c': 19.5,
#       'temp_f': 67.1,
#       'is_day': 0,
#       'condition': {'text': 'Clear ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 4.0,
#       'wind_kph': 6.5,
#       'wind_degree': 270,
#       'wind_dir': 'W',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.94,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 83,
#       'cloud': 15,
#       'feelslike_c': 19.5,
#       'feelslike_f': 67.1,
#       'windchill_c': 19.5,
#       'windchill_f': 67.1,
#       'heatindex_c': 19.5,
#       'heatindex_f': 67.1,
#       'dewpoint_c': 16.6,
#       'dewpoint_f': 61.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.5,
#       'gust_kph': 13.6,
#       'uv': 1.0},
#      {'time_epoch': 1709276400,
#       'time': '2024-03-01 04:00',
#       'temp_c': 19.4,
#       'temp_f': 66.8,
#       'is_day': 0,
#       'condition': {'text': 'Clear ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 3.1,
#       'wind_kph': 5.0,
#       'wind_degree': 271,
#       'wind_dir': 'W',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.92,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 83,
#       'cloud': 17,
#       'feelslike_c': 19.4,
#       'feelslike_f': 66.8,
#       'windchill_c': 19.4,
#       'windchill_f': 66.8,
#       'heatindex_c': 19.4,
#       'heatindex_f': 66.8,
#       'dewpoint_c': 16.3,
#       'dewpoint_f': 61.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.5,
#       'gust_kph': 10.4,
#       'uv': 1.0},
#      {'time_epoch': 1709280000,
#       'time': '2024-03-01 05:00',
#       'temp_c': 18.9,
#       'temp_f': 66.0,
#       'is_day': 0,
#       'condition': {'text': 'Clear ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 2.5,
#       'wind_kph': 4.0,
#       'wind_degree': 285,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.92,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 83,
#       'cloud': 22,
#       'feelslike_c': 18.9,
#       'feelslike_f': 66.0,
#       'windchill_c': 18.9,
#       'windchill_f': 66.0,
#       'heatindex_c': 18.9,
#       'heatindex_f': 66.0,
#       'dewpoint_c': 15.9,
#       'dewpoint_f': 60.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.1,
#       'gust_kph': 8.1,
#       'uv': 1.0},
#      {'time_epoch': 1709283600,
#       'time': '2024-03-01 06:00',
#       'temp_c': 18.5,
#       'temp_f': 65.2,
#       'is_day': 0,
#       'condition': {'text': 'Clear ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 2.5,
#       'wind_kph': 4.0,
#       'wind_degree': 277,
#       'wind_dir': 'W',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.94,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 84,
#       'cloud': 21,
#       'feelslike_c': 18.5,
#       'feelslike_f': 65.2,
#       'windchill_c': 18.5,
#       'windchill_f': 65.2,
#       'heatindex_c': 18.5,
#       'heatindex_f': 65.2,
#       'dewpoint_c': 15.6,
#       'dewpoint_f': 60.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.0,
#       'gust_kph': 8.0,
#       'uv': 1.0},
#      {'time_epoch': 1709287200,
#       'time': '2024-03-01 07:00',
#       'temp_c': 17.6,
#       'temp_f': 63.7,
#       'is_day': 0,
#       'condition': {'text': 'Clear ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 3.1,
#       'wind_kph': 5.0,
#       'wind_degree': 284,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.95,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 84,
#       'cloud': 19,
#       'feelslike_c': 17.6,
#       'feelslike_f': 63.7,
#       'windchill_c': 17.6,
#       'windchill_f': 63.7,
#       'heatindex_c': 17.6,
#       'heatindex_f': 63.7,
#       'dewpoint_c': 15.0,
#       'dewpoint_f': 58.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.6,
#       'gust_kph': 10.6,
#       'uv': 1.0},
#      {'time_epoch': 1709290800,
#       'time': '2024-03-01 08:00',
#       'temp_c': 19.1,
#       'temp_f': 66.3,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 3.6,
#       'wind_kph': 5.8,
#       'wind_degree': 281,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.97,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 85,
#       'cloud': 19,
#       'feelslike_c': 19.1,
#       'feelslike_f': 66.3,
#       'windchill_c': 19.1,
#       'windchill_f': 66.3,
#       'heatindex_c': 19.1,
#       'heatindex_f': 66.3,
#       'dewpoint_c': 16.4,
#       'dewpoint_f': 61.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.4,
#       'gust_kph': 10.3,
#       'uv': 6.0},
#      {'time_epoch': 1709294400,
#       'time': '2024-03-01 09:00',
#       'temp_c': 22.0,
#       'temp_f': 71.5,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 1.6,
#       'wind_kph': 2.5,
#       'wind_degree': 276,
#       'wind_dir': 'W',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.96,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 76,
#       'cloud': 15,
#       'feelslike_c': 22.0,
#       'feelslike_f': 71.5,
#       'windchill_c': 22.0,
#       'windchill_f': 71.5,
#       'heatindex_c': 24.5,
#       'heatindex_f': 76.1,
#       'dewpoint_c': 17.6,
#       'dewpoint_f': 63.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 1.8,
#       'gust_kph': 2.9,
#       'uv': 7.0},
#      {'time_epoch': 1709298000,
#       'time': '2024-03-01 10:00',
#       'temp_c': 24.5,
#       'temp_f': 76.0,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 0.9,
#       'wind_kph': 1.4,
#       'wind_degree': 135,
#       'wind_dir': 'SE',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.95,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 67,
#       'cloud': 12,
#       'feelslike_c': 26.0,
#       'feelslike_f': 78.8,
#       'windchill_c': 24.5,
#       'windchill_f': 76.0,
#       'heatindex_c': 26.0,
#       'heatindex_f': 78.8,
#       'dewpoint_c': 17.9,
#       'dewpoint_f': 64.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 1.0,
#       'gust_kph': 1.7,
#       'uv': 7.0},
#      {'time_epoch': 1709301600,
#       'time': '2024-03-01 11:00',
#       'temp_c': 26.6,
#       'temp_f': 79.9,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 2.2,
#       'wind_kph': 3.6,
#       'wind_degree': 90,
#       'wind_dir': 'E',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.93,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 59,
#       'cloud': 13,
#       'feelslike_c': 27.8,
#       'feelslike_f': 82.1,
#       'windchill_c': 26.6,
#       'windchill_f': 79.9,
#       'heatindex_c': 27.8,
#       'heatindex_f': 82.1,
#       'dewpoint_c': 18.0,
#       'dewpoint_f': 64.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 2.6,
#       'gust_kph': 4.1,
#       'uv': 8.0},
#      {'time_epoch': 1709305200,
#       'time': '2024-03-01 12:00',
#       'temp_c': 27.6,
#       'temp_f': 81.7,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 4.5,
#       'wind_kph': 7.2,
#       'wind_degree': 86,
#       'wind_dir': 'E',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.9,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 55,
#       'cloud': 10,
#       'feelslike_c': 28.7,
#       'feelslike_f': 83.6,
#       'windchill_c': 27.6,
#       'windchill_f': 81.7,
#       'heatindex_c': 28.7,
#       'heatindex_f': 83.6,
#       'dewpoint_c': 17.7,
#       'dewpoint_f': 63.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.1,
#       'gust_kph': 8.3,
#       'uv': 8.0},
#      {'time_epoch': 1709308800,
#       'time': '2024-03-01 13:00',
#       'temp_c': 28.4,
#       'temp_f': 83.1,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 5.4,
#       'wind_kph': 8.6,
#       'wind_degree': 88,
#       'wind_dir': 'E',
#       'pressure_mb': 1012.0,
#       'pressure_in': 29.87,
#       'precip_mm': 0.01,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 53,
#       'cloud': 83,
#       'feelslike_c': 29.5,
#       'feelslike_f': 85.0,
#       'windchill_c': 28.4,
#       'windchill_f': 83.1,
#       'heatindex_c': 29.5,
#       'heatindex_f': 85.0,
#       'dewpoint_c': 17.7,
#       'dewpoint_f': 63.9,
#       'will_it_rain': 1,
#       'chance_of_rain': 73,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.2,
#       'gust_kph': 9.9,
#       'uv': 7.0},
#      {'time_epoch': 1709312400,
#       'time': '2024-03-01 14:00',
#       'temp_c': 28.8,
#       'temp_f': 83.8,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 5.4,
#       'wind_kph': 8.6,
#       'wind_degree': 83,
#       'wind_dir': 'E',
#       'pressure_mb': 1011.0,
#       'pressure_in': 29.84,
#       'precip_mm': 0.24,
#       'precip_in': 0.01,
#       'snow_cm': 0.0,
#       'humidity': 51,
#       'cloud': 86,
#       'feelslike_c': 29.9,
#       'feelslike_f': 85.7,
#       'windchill_c': 28.8,
#       'windchill_f': 83.8,
#       'heatindex_c': 29.9,
#       'heatindex_f': 85.7,
#       'dewpoint_c': 17.8,
#       'dewpoint_f': 64.0,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 9.0,
#       'vis_miles': 5.0,
#       'gust_mph': 6.2,
#       'gust_kph': 9.9,
#       'uv': 7.0},
#      {'time_epoch': 1709316000,
#       'time': '2024-03-01 15:00',
#       'temp_c': 28.7,
#       'temp_f': 83.7,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 5.4,
#       'wind_kph': 8.6,
#       'wind_degree': 76,
#       'wind_dir': 'ENE',
#       'pressure_mb': 1010.0,
#       'pressure_in': 29.81,
#       'precip_mm': 0.01,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 52,
#       'cloud': 80,
#       'feelslike_c': 29.9,
#       'feelslike_f': 85.7,
#       'windchill_c': 28.7,
#       'windchill_f': 83.7,
#       'heatindex_c': 29.9,
#       'heatindex_f': 85.7,
#       'dewpoint_c': 17.9,
#       'dewpoint_f': 64.1,
#       'will_it_rain': 1,
#       'chance_of_rain': 79,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.2,
#       'gust_kph': 9.9,
#       'uv': 7.0},
#      {'time_epoch': 1709319600,
#       'time': '2024-03-01 16:00',
#       'temp_c': 27.8,
#       'temp_f': 82.1,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 5.6,
#       'wind_kph': 9.0,
#       'wind_degree': 58,
#       'wind_dir': 'ENE',
#       'pressure_mb': 1009.0,
#       'pressure_in': 29.79,
#       'precip_mm': 0.02,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 58,
#       'cloud': 79,
#       'feelslike_c': 29.2,
#       'feelslike_f': 84.6,
#       'windchill_c': 27.8,
#       'windchill_f': 82.1,
#       'heatindex_c': 29.2,
#       'heatindex_f': 84.6,
#       'dewpoint_c': 18.7,
#       'dewpoint_f': 65.7,
#       'will_it_rain': 1,
#       'chance_of_rain': 79,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.4,
#       'gust_kph': 10.4,
#       'uv': 7.0},
#      {'time_epoch': 1709323200,
#       'time': '2024-03-01 17:00',
#       'temp_c': 26.8,
#       'temp_f': 80.3,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 4.7,
#       'wind_kph': 7.6,
#       'wind_degree': 40,
#       'wind_dir': 'NE',
#       'pressure_mb': 1008.0,
#       'pressure_in': 29.78,
#       'precip_mm': 0.06,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 64,
#       'cloud': 88,
#       'feelslike_c': 28.4,
#       'feelslike_f': 83.2,
#       'windchill_c': 26.8,
#       'windchill_f': 80.3,
#       'heatindex_c': 28.4,
#       'heatindex_f': 83.2,
#       'dewpoint_c': 19.4,
#       'dewpoint_f': 67.0,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.4,
#       'gust_kph': 8.7,
#       'uv': 7.0},
#      {'time_epoch': 1709326800,
#       'time': '2024-03-01 18:00',
#       'temp_c': 27.0,
#       'temp_f': 80.6,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 6.9,
#       'wind_kph': 11.2,
#       'wind_degree': 50,
#       'wind_dir': 'NE',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.97,
#       'precip_mm': 0.08,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 66,
#       'cloud': 50,
#       'feelslike_c': 27.1,
#       'feelslike_f': 80.8,
#       'windchill_c': 25.6,
#       'windchill_f': 78.1,
#       'heatindex_c': 27.1,
#       'heatindex_f': 80.8,
#       'dewpoint_c': 19.0,
#       'dewpoint_f': 66.3,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.4,
#       'gust_kph': 18.4,
#       'uv': 7.0},
#      {'time_epoch': 1709330400,
#       'time': '2024-03-01 19:00',
#       'temp_c': 22.5,
#       'temp_f': 72.6,
#       'is_day': 1,
#       'condition': {'text': 'Patchy light drizzle',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/263.png',
#        'code': 1150},
#       'wind_mph': 2.9,
#       'wind_kph': 4.7,
#       'wind_degree': 304,
#       'wind_dir': 'NW',
#       'pressure_mb': 1009.0,
#       'pressure_in': 29.8,
#       'precip_mm': 0.71,
#       'precip_in': 0.03,
#       'snow_cm': 0.0,
#       'humidity': 74,
#       'cloud': 79,
#       'feelslike_c': 24.8,
#       'feelslike_f': 76.6,
#       'windchill_c': 22.5,
#       'windchill_f': 72.6,
#       'heatindex_c': 24.8,
#       'heatindex_f': 76.6,
#       'dewpoint_c': 17.7,
#       'dewpoint_f': 63.9,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 5.0,
#       'vis_miles': 3.0,
#       'gust_mph': 6.1,
#       'gust_kph': 9.8,
#       'uv': 6.0},
#      {'time_epoch': 1709334000,
#       'time': '2024-03-01 20:00',
#       'temp_c': 20.6,
#       'temp_f': 69.1,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 3.4,
#       'wind_kph': 5.4,
#       'wind_degree': 305,
#       'wind_dir': 'NW',
#       'pressure_mb': 1010.0,
#       'pressure_in': 29.82,
#       'precip_mm': 0.01,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 78,
#       'cloud': 86,
#       'feelslike_c': 20.6,
#       'feelslike_f': 69.1,
#       'windchill_c': 20.6,
#       'windchill_f': 69.1,
#       'heatindex_c': 20.6,
#       'heatindex_f': 69.1,
#       'dewpoint_c': 16.5,
#       'dewpoint_f': 61.8,
#       'will_it_rain': 1,
#       'chance_of_rain': 78,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.0,
#       'gust_kph': 11.3,
#       'uv': 1.0},
#      {'time_epoch': 1709337600,
#       'time': '2024-03-01 21:00',
#       'temp_c': 20.4,
#       'temp_f': 68.8,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 3.4,
#       'wind_kph': 5.4,
#       'wind_degree': 287,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1010.0,
#       'pressure_in': 29.83,
#       'precip_mm': 0.03,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 77,
#       'cloud': 54,
#       'feelslike_c': 20.4,
#       'feelslike_f': 68.8,
#       'windchill_c': 20.4,
#       'windchill_f': 68.8,
#       'heatindex_c': 20.4,
#       'heatindex_f': 68.8,
#       'dewpoint_c': 16.3,
#       'dewpoint_f': 61.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 67,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.0,
#       'gust_kph': 11.3,
#       'uv': 1.0},
#      {'time_epoch': 1709341200,
#       'time': '2024-03-01 22:00',
#       'temp_c': 20.4,
#       'temp_f': 68.8,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 3.6,
#       'wind_kph': 5.8,
#       'wind_degree': 287,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1011.0,
#       'pressure_in': 29.87,
#       'precip_mm': 0.03,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 77,
#       'cloud': 56,
#       'feelslike_c': 20.4,
#       'feelslike_f': 68.8,
#       'windchill_c': 20.4,
#       'windchill_f': 68.8,
#       'heatindex_c': 20.4,
#       'heatindex_f': 68.8,
#       'dewpoint_c': 16.2,
#       'dewpoint_f': 61.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 61,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.5,
#       'gust_kph': 12.1,
#       'uv': 1.0},
#      {'time_epoch': 1709344800,
#       'time': '2024-03-01 23:00',
#       'temp_c': 20.3,
#       'temp_f': 68.6,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 3.8,
#       'wind_kph': 6.1,
#       'wind_degree': 285,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1012.0,
#       'pressure_in': 29.88,
#       'precip_mm': 0.02,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 77,
#       'cloud': 89,
#       'feelslike_c': 20.3,
#       'feelslike_f': 68.6,
#       'windchill_c': 20.3,
#       'windchill_f': 68.6,
#       'heatindex_c': 20.3,
#       'heatindex_f': 68.6,
#       'dewpoint_c': 16.1,
#       'dewpoint_f': 61.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 60,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.0,
#       'gust_kph': 12.9,
#       'uv': 1.0}]}]}}

# %%
response.keys()
# Out:
# dict_keys(['location', 'current', 'forecast'])

# %%
response['forecast']['forecastday'][0].keys()
# Out:
# dict_keys(['date', 'date_epoch', 'day', 'astro', 'hour'])

# %%
len(response['forecast']['forecastday'][0]['hour'])
# Out:
# 24

# %%
response['forecast']['forecastday'][0]['hour'][1]
# Out:
# {'time_epoch': 1709265600,
#  'time': '2024-03-01 01:00',
#  'temp_c': 19.5,
#  'temp_f': 67.2,
#  'is_day': 0,
#  'condition': {'text': 'Partly Cloudy ',
#   'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#   'code': 1003},
#  'wind_mph': 4.5,
#  'wind_kph': 7.2,
#  'wind_degree': 281,
#  'wind_dir': 'WNW',
#  'pressure_mb': 1015.0,
#  'pressure_in': 29.97,
#  'precip_mm': 0.0,
#  'precip_in': 0.0,
#  'snow_cm': 0.0,
#  'humidity': 86,
#  'cloud': 25,
#  'feelslike_c': 19.6,
#  'feelslike_f': 67.2,
#  'windchill_c': 19.6,
#  'windchill_f': 67.2,
#  'heatindex_c': 19.6,
#  'heatindex_f': 67.2,
#  'dewpoint_c': 17.1,
#  'dewpoint_f': 62.8,
#  'will_it_rain': 0,
#  'chance_of_rain': 0,
#  'will_it_snow': 0,
#  'chance_of_snow': 0,
#  'vis_km': 10.0,
#  'vis_miles': 6.0,
#  'gust_mph': 9.4,
#  'gust_kph': 15.1,
#  'uv': 1.0}

# %%
response['forecast']['forecastday'][0]['hour'][0]['time'].split()[0] #Fecha
# Out:
# '2024-03-01'

# %%
int(response['forecast']['forecastday'][0]['hour'][1]['time'].split()[1].split(':')[0]) #Hora
# Out:
# 1

# %%
response['forecast']['forecastday'][0]['hour'][0]['condition']['text'] #Condicion
# Out:
# 'Patchy rain nearby'

# %%
response['forecast']['forecastday'][0]['hour'][0]['temp_c'] #Temperatura
# Out:
# 18.7

# %%
response['forecast']['forecastday'][0]['hour'][0]['will_it_rain'] #Llovera o no, 0 para no, 1 para si
# Out:
# 1

# %%
response['forecast']['forecastday'][0]['hour'][1]['chance_of_rain'] #Posibilidad de lluvia
# Out:
# 0

# %% [markdown]
# # Dataframe

# %%
def get_forecast(response,i):

    fecha = response['forecast']['forecastday'][0]['hour'][i]['time'].split()[0] #Fecha
    hora = int(response['forecast']['forecastday'][0]['hour'][i]['time'].split()[1].split(':')[0]) #Hora
    condicion = response['forecast']['forecastday'][0]['hour'][i]['condition']['text'] #Condicion
    tempe = response['forecast']['forecastday'][0]['hour'][i]['temp_c'] #Temperatura
    rain = response['forecast']['forecastday'][0]['hour'][i]['will_it_rain'] #Llovera o no, 0 para no, 1 para si
    prob_rain = response['forecast']['forecastday'][0]['hour'][i]['chance_of_rain'] #Posibilidad de lluvia

    return fecha,hora,condicion,tempe,rain,prob_rain

# %%
datos = []

for i in tqdm(range(len(response['forecast']['forecastday'][0]['hour'])),colour = 'green'):
#tqdm es para visualizar una barra de carga en las iteraciones del for
    datos.append(get_forecast(response,i))
# Out:
# 100%|██████████| 24/24 [00:00<?, ?it/s]

# %%
datos[0]
# Out:
# ('2024-03-01', 0, 'Patchy rain nearby', 18.7, 1, 100)

# %%
col = ['Fecha','Hora','Condicion','Temperatura','Lluvia','prob_lluvia']
df = pd.DataFrame(datos,columns=col)

# %%
df
# Out:
#          Fecha  Hora             Condicion  Temperatura  Lluvia  prob_lluvia
# 0   2024-03-01     0    Patchy rain nearby         18.7       1          100
# 1   2024-03-01     1        Partly Cloudy          19.5       0            0
# 2   2024-03-01     2                Clear          19.6       0            0
# 3   2024-03-01     3                Clear          19.5       0            0
# 4   2024-03-01     4                Clear          19.4       0            0
# 5   2024-03-01     5                Clear          18.9       0            0
# 6   2024-03-01     6                Clear          18.5       0            0
# 7   2024-03-01     7                Clear          17.6       0            0
# 8   2024-03-01     8                 Sunny         19.1       0            0
# 9   2024-03-01     9                 Sunny         22.0       0            0
# 10  2024-03-01    10                 Sunny         24.5       0            0
# 11  2024-03-01    11                 Sunny         26.6       0            0
# 12  2024-03-01    12                 Sunny         27.6       0            0
# 13  2024-03-01    13    Patchy rain nearby         28.4       1           73
# 14  2024-03-01    14    Patchy rain nearby         28.8       1          100
# 15  2024-03-01    15    Patchy rain nearby         28.7       1           79
# 16  2024-03-01    16    Patchy rain nearby         27.8       1           79
# 17  2024-03-01    17    Patchy rain nearby         26.8       1          100
# 18  2024-03-01    18         Partly cloudy         27.0       1          100
# 19  2024-03-01    19  Patchy light drizzle         22.5       1          100
# 20  2024-03-01    20    Patchy rain nearby         20.6       1           78
# 21  2024-03-01    21    Patchy rain nearby         20.4       0           67
# 22  2024-03-01    22    Patchy rain nearby         20.4       0           61
# 23  2024-03-01    23    Patchy rain nearby         20.3       0           60

# %%
df_rain = df[(df['Lluvia']==1) & (df['Hora']>6) & (df['Hora']< 23)]
df_rain = df_rain[['Hora','Condicion']]
df_rain.set_index('Hora', inplace = True)

# %%
df_rain
# Out:
#                  Condicion
# Hora
# 13      Patchy rain nearby
# 14      Patchy rain nearby
# 15      Patchy rain nearby
# 16      Patchy rain nearby
# 17      Patchy rain nearby
# 18           Partly cloudy
# 19    Patchy light drizzle
# 20      Patchy rain nearby

# %% [markdown]
# # Mensaje desde Bot de Telegram

# %%
# !pip3 install googletrans==4.0.0-rc1
# Out:
# Requirement already satisfied: googletrans==4.0.0-rc1 in c:\users\outlet\appdata\local\programs\python\python311\lib\site-packages (4.0.0rc1)
# Requirement already satisfied: httpx==0.13.3 in c:\users\outlet\appdata\local\programs\python\python311\lib\site-packages (from googletrans==4.0.0-rc1) (0.13.3)
# Requirement already satisfied: certifi in c:\users\outlet\appdata\local\programs\python\python311\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2022.12.7)
# Requirement already satisfied: hstspreload in c:\users\outlet\appdata\local\programs\python\python311\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2024.3.1)
# Requirement already satisfied: sniffio in c:\users\outlet\appdata\roaming\python\python311\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.3.0)
# Requirement already satisfied: chardet==3.* in c:\users\outlet\appdata\local\programs\python\python311\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.4)
# Requirement already satisfied: idna==2.* in c:\users\outlet\appdata\local\programs\python\python311\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2.10)
# Requirement already satisfied: rfc3986<2,>=1.3 in c:\users\outlet\appdata\local\programs\python\python311\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.5.0)
# Requirement already satisfied: httpcore==0.9.* in c:\users\outlet\appdata\local\programs\python\python311\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.1)
# Requirement already satisfied: h11<0.10,>=0.8 in c:\users\outlet\appdata\local\programs\python\python311\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.0)
# Requirement already satisfied: h2==3.* in c:\users\outlet\appdata\local\programs\python\python311\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in c:\users\outlet\appdata\local\programs\python\python311\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in c:\users\outlet\appdata\local\programs\python\python311\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.0)
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
from googletrans import Translator
import telegram_config
import pandas as pd

def enviar_mensaje_telegram(mensaje, df_rain):
    token = telegram_config.TOKEN
    url = f"https://api.telegram.org/bot{token}/sendMessage"
    
    # Convertir la columna 'Fecha' al formato de fecha deseado (si aún no está en ese formato)
    df['Fecha'] = pd.to_datetime(df['Fecha'])
    # Modificar el formato de fecha a 'dd/mm/aaaa'
    df['Fecha'] = df['Fecha'].dt.strftime('%d/%m/%Y')

    # Crear una instancia del traductor
    translator = Translator()

    # Iterar sobre cada fila del DataFrame y traducir el texto en la columna "Condicion"
    for index, row in df_rain.iterrows():
        # Obtener el texto en la columna "Condicion"
        texto_a_traducir = row['Condicion']

        # Traducir el texto al idioma deseado, por ejemplo, al español ('es')
        texto_traducido = translator.translate(texto_a_traducir, dest='es').text

        # Actualizar el valor en la columna "Condicion" con el texto traducido
        df_rain.at[index, 'Condicion'] = texto_traducido
    
    parametros = {
        'chat_id': 5410219790,
        'text': mensaje
    }
    
    try:
        respuesta = requests.post(url, data=parametros)
        datos_respuesta = respuesta.json()
        if datos_respuesta['ok']:
            print("Mensaje enviado exitosamente.")
        else:
            print(f"No se pudo enviar el mensaje: {datos_respuesta['descripcion']}")
    except Exception as e:
        print(f"Error al enviar el mensaje: {str(e)}")

# Llamada de ejemplo
# Construcción del mensaje mejorado
mensaje = f"""
Hola!
El pronóstico de lluvia para hoy {df['Fecha'][0]} en {query} es el siguiente:

{df_rain.to_string()}
"""

# Envío del mensaje
enviar_mensaje_telegram(mensaje, df_rain)
# Out:
# Mensaje enviado exitosamente.

# %% [markdown]
# # Challenge
#
# * Extrae el valor del dolar en tu país y el top 10 de criptomonedas con su respectiva valoración
# * Ahora envia un mensaje diarío a tu Whatsapp usando Twilio
#
# **hint 💡** Investiga que API's gratuitas existen para consultar estos datos
#
#
#
# <img src="WhatsApp Image 2022-09-13 at 9.12.18 AM.jpeg" width="200" height="200" />
